# %% [markdown]
# # L: Data Lake and Warehouse

# %%
import os
from datetime import datetime
import pandas as pd
import requests
import pandas as pd
import sqlite3
from bs4 import BeautifulSoup

# %% [markdown]
# ## Web Scraping

# %%
STORAGE_DIR = "local"

# %%
# List of news pages to be scraped
newspaper_urls = dict(
    sz="https://www.sueddeutsche.de/",
    zeit="https://www.zeit.de/index",
    faz="https://www.faz.net/aktuell/",
    ts="https://www.tagesspiegel.de/",
    spiegel="https://www.spiegel.de/",
    kronen="https://www.krone.at/",
    wtf="https://asdfkajwlkejwkejklajsdflksadjfasdf.nix",
)

# %%
# Current date as string
now = datetime.now()
now_str = now.strftime("%Y-%m-%d")
print(now_str)
# Out:
# 2021-03-23

# %%
content_dict = {}
text_dict = {}
log_list = []
failing_list = []

# %%
def scrape_website(name, url):
    
    # (1) Run request
    response = requests.get(url, allow_redirects=True)
    content = response.content
    text = response.text
    
    # (2) File name to store the raw HTML
    file_name = os.path.join(
        STORAGE_DIR,
        f"{now_str}-{name}.html",
    )
    
    # (3) Write raw HTML
    with open(file_name, "wb") as f:
        f.write(response.content)
        
    # (4) Fill content_dict and text_dict
    content_dict[name] = response.content
    text_dict[name] = response.text
    
    # (5) Fill log_list
    log_info = dict(
        name=name,
        date=now_str,
        file_name=file_name,
        status=response.status_code,
        url=response.url,
        encoding=response.encoding,
    )
    log_list.append(log_info)

# %%
for name, url in newspaper_urls.items():
    try:
        scrape_website(name, url)
    except:
        failing_list.append((name, url))

# %%
log_df = pd.DataFrame(log_list)
log_df
# Out:
#       name        date                      file_name  status  \
# 0       sz  2021-03-23       local\2021-03-23-sz.html     200
# 1     zeit  2021-03-23     local\2021-03-23-zeit.html     200
# 2      faz  2021-03-23      local\2021-03-23-faz.html     200
# 3       ts  2021-03-23       local\2021-03-23-ts.html     200
# 4  spiegel  2021-03-23  local\2021-03-23-spiegel.html     200
# 5   kronen  2021-03-23   local\2021-03-23-kronen.html     200
#
#                             url    encoding
# 0  https://www.sueddeutsche.de/       UTF-8
# 1     https://www.zeit.de/index       UTF-8
# 2  https://www.faz.net/aktuell/       utf-8
# 3  https://www.tagesspiegel.de/       utf-8
# 4       https://www.spiegel.de/       utf-8
# 5         https://www.krone.at/  ISO-8859-1

# %%
log_file_name = os.path.join(
    STORAGE_DIR,
    f"{now_str}.csv",
)

# %%
log_df.to_csv(log_file_name)

# %% [markdown]
# ## Word Count

# %%
stopwords_url = "https://raw.githubusercontent.com/solariz/german_stopwords/master/german_stopwords_full.txt"
stopwords_list = requests.get(stopwords_url, allow_redirects=True).text.split("\n")[9:]

# %%
def process_html(text):
    text = BeautifulSoup(text, "html.parser").text
    items = text.replace("\n", " ").lower().split(" ")
    items = [i for i in items if len(i) > 1 and i not in stopwords_list]
    return items

# %%
data = pd.DataFrame()
for name, text in text_dict.items():
    items = process_html(text)
    new = pd.Series(items).value_counts().to_frame()
    new.columns = ["count"]
    new["word"] = new.index
    new["name"] = name
    new["date"] = now_str
    data = pd.concat([data, new])

# %%
data
# Out:
#                                     count                                word  \
# bilder                                 82                              bilder
# sz                                     59                                  sz
# gutschein                              40                           gutschein
# plus                                   33                                plus
# momentaufnahmen                        22                     momentaufnahmen
# ...                                   ...                                 ...
# geben!unterhaus                         1                     geben!unterhaus
# warmâkroneâ-wetter-updatewoche      1  warmâkroneâ-wetter-updatewoche
# pernsteiner                             1                         pernsteiner
# kã¼chenmaschine                         1                     kã¼chenmaschine
# polen!sportwetten                       1                   polen!sportwetten
#
#                                       name        date
# bilder                                  sz  2021-03-23
# sz                                      sz  2021-03-23
# gutschein                               sz  2021-03-23
# plus                                    sz  2021-03-23
# momentaufnahmen                         sz  2021-03-23
# ...                                    ...         ...
# geben!unterhaus                     kronen  2021-03-23
# warmâkroneâ-wetter-updatewoche  kronen  2021-03-23
# pernsteiner                         kronen  2021-03-23
# kã¼chenmaschine                     kronen  2021-03-23
# polen!sportwetten                   kronen  2021-03-23
#
# [11408 rows x 4 columns]

# %%
data.loc[data["word"].str.contains("impfung"),]
# Out:
#                                    count                               word  \
# impfungen                              1                          impfungen
# corona-impfung                         2                     corona-impfung
# corona-impfung:                        1                    corona-impfung:
# impfungen                              1                          impfungen
# corona-impfungen                       1                   corona-impfungen
# \t\t\t\t\t\t\t\t\t\t\t\timpfungen      1  \t\t\t\t\t\t\t\t\t\t\t\timpfungen
# astra-zeneca-impfung                   1               astra-zeneca-impfung
# impfungen                              2                          impfungen
# impfung                                2                            impfung
# corona-impfung                         1                     corona-impfung
# impfung                                1                            impfung
#
#                                      name        date
# impfungen                              sz  2021-03-23
# corona-impfung                       zeit  2021-03-23
# corona-impfung:                      zeit  2021-03-23
# impfungen                            zeit  2021-03-23
# corona-impfungen                     zeit  2021-03-23
# \t\t\t\t\t\t\t\t\t\t\t\timpfungen     faz  2021-03-23
# astra-zeneca-impfung                  faz  2021-03-23
# impfungen                              ts  2021-03-23
# impfung                                ts  2021-03-23
# corona-impfung                         ts  2021-03-23
# impfung                            kronen  2021-03-23

# %% [markdown]
# ## SQLite

# %%
SQL_PATH = os.path.join("dwh.sqlite3")

# %%
connection = sqlite3.connect(SQL_PATH)
data.to_sql("wordcount", connection, index=False, if_exists="append")
